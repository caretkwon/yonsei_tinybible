# %% [markdown]
# <a href="https://colab.research.google.com/github/caretkwon/yonsei_tinybible/blob/260622_01/notebook_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 6 — Toward a Tiny GPT
#
# 이제 남은 모듈들을 하나씩 추가하여 **좀 더 GPT다운 구조**로 갑니다.
#
# 이번 노트북에서 추가하는 것들:
#
# - multi-head attention
# - feedforward network
# - residual connection
# - layer normalization
# - block stacking

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

# Ensure input.txt exists and is not empty
input_file_path = Path("input.txt")

# If the file doesn't exist or is empty, try downloading it
if not input_file_path.exists() or input_file_path.stat().st_size == 0:
    print("Downloading King James Bible...")
    # Remove existing file to ensure a fresh download in case of corruption
    if input_file_path.exists():
        input_file_path.unlink()
    # !wget -q https://www.gutenberg.org/files/10/10-0.txt -O input.txt

text = open("input.txt", "r", encoding="utf-8").read()

# Critical check: if text is still empty after download attempt and read
if not text:
    raise ValueError("Downloaded text file is empty. Please check the download URL or network connection.")

chars = sorted(list(set(text)))
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for ch, i in stoi.items()}
vocab_size = len(chars)
data = torch.tensor([stoi[ch] for ch in text], dtype=torch.long)

class NextTokenDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        # Ensure that the dataset length is never negative
        return max(0, len(self.data) - self.block_size)

    def __getitem__(self, idx):
        x = self.data[idx : idx + self.block_size]
        y = self.data[idx + 1 : idx + self.block_size + 1]
        return x, y

block_size = 64

# Another critical check: Ensure data has enough length for block_size
# We need at least block_size + 1 elements for x and y to be non-empty and correctly shifted
if len(data) < block_size + 1:
    raise ValueError(
        f"Dataset is too small ({len(data)} characters) for the specified block_size ({block_size}). "
        "Please use a smaller block_size or ensure a larger text file is downloaded."
    )

dataset = NextTokenDataset(data, block_size)
loader = DataLoader(dataset, batch_size=64, shuffle=True)
xb, yb = next(iter(loader))

# %% [markdown]
# ## 1. Multi-head attention

# %%
class Head(nn.Module):
    def __init__(self, emb_dim, head_size, block_size, dropout=0.1):
        super().__init__()
        self.key = nn.Linear(emb_dim, head_size, bias=False)
        self.query = nn.Linear(emb_dim, head_size, bias=False)
        self.value = nn.Linear(emb_dim, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        v = self.value(x)
        wei = q @ k.transpose(-2, -1) * (k.size(-1) ** -0.5)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float("-inf"))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, emb_dim, num_heads, block_size, dropout=0.1):
        super().__init__()
        head_size = emb_dim // num_heads
        self.heads = nn.ModuleList([Head(emb_dim, head_size, block_size, dropout) for _ in range(num_heads)])
        self.proj = nn.Linear(emb_dim, emb_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.proj(out)
        out = self.dropout(out)
        return out

# %% [markdown]
# ## 2. Feedforward + Block

# %%
class FeedForward(nn.Module):
    def __init__(self, emb_dim, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(emb_dim, 4 * emb_dim),
            nn.ReLU(),
            nn.Linear(4 * emb_dim, emb_dim),
            nn.Dropout(dropout),
        )
    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, emb_dim, num_heads, block_size, dropout=0.1):
        super().__init__()
        self.ln1 = nn.LayerNorm(emb_dim)
        self.sa = MultiHeadAttention(emb_dim, num_heads, block_size, dropout)
        self.ln2 = nn.LayerNorm(emb_dim)
        self.ffwd = FeedForward(emb_dim, dropout)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# %% [markdown]
# ## 3. Tiny GPT

# %%
class TinyGPT(nn.Module):
    def __init__(self, vocab_size, block_size, emb_dim=128, num_heads=4, num_layers=4, dropout=0.1):
        super().__init__()
        self.token_embedding = nn.Embedding(vocab_size, emb_dim)
        self.position_embedding = nn.Embedding(block_size, emb_dim)
        self.blocks = nn.Sequential(*[
            Block(emb_dim, num_heads, block_size, dropout) for _ in range(num_layers)
        ])
        self.ln_f = nn.LayerNorm(emb_dim)
        self.lm_head = nn.Linear(emb_dim, vocab_size)

    def forward(self, x):
        B, T = x.shape
        pos = torch.arange(T, device=x.device)
        tok = self.token_embedding(x)
        pos = self.position_embedding(pos)[None]
        h = tok + pos
        h = self.blocks(h)
        h = self.ln_f(h)
        logits = self.lm_head(h)
        return logits

model = TinyGPT(vocab_size, block_size)
logits = model(xb)
print("logits.shape:", logits.shape)
# Out:
# logits.shape: torch.Size([64, 64, 74])

# %% [markdown]
# ## 4. 학습

# %%
def sequence_cross_entropy(logits, targets):
    return F.cross_entropy(logits.transpose(1, 2), targets)

def train_one_epoch(model, loader, optimizer, device, max_steps=None):
    model.train()
    total_loss, total_count = 0.0, 0
    for step, (xb, yb) in enumerate(loader):
        xb, yb = xb.to(device), yb.to(device)
        logits = model(xb)
        loss = sequence_cross_entropy(logits, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * xb.size(0)
        total_count += xb.size(0)
        if max_steps is not None and step + 1 >= max_steps:
            break
    return total_loss / total_count

device = "cuda" if torch.cuda.is_available() else "cpu"
model = TinyGPT(vocab_size, block_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)

for epoch in range(100):
    train_loss = train_one_epoch(model, loader, optimizer, device, max_steps=300)
    print(f"epoch {epoch:2d} | train loss {train_loss:.4f}")
# Out:
# epoch  0 | train loss 2.5288
# epoch  1 | train loss 2.0851
# epoch  2 | train loss 1.8750
# epoch  3 | train loss 1.7439
# epoch  4 | train loss 1.6535
# epoch  5 | train loss 1.5918
# epoch  6 | train loss 1.5406
# epoch  7 | train loss 1.5037
# epoch  8 | train loss 1.4740
# epoch  9 | train loss 1.4481
# epoch 10 | train loss 1.4247
# epoch 11 | train loss 1.4076
# epoch 12 | train loss 1.3883
# epoch 13 | train loss 1.3723
# epoch 14 | train loss 1.3595
# epoch 15 | train loss 1.3467
# epoch 16 | train loss 1.3367
# epoch 17 | train loss 1.3303
# epoch 18 | train loss 1.3204
# epoch 19 | train loss 1.3126
# epoch 20 | train loss 1.3070
# epoch 21 | train loss 1.2972
# epoch 22 | train loss 1.2938
# epoch 23 | train loss 1.2858
# epoch 24 | train loss 1.2807
# epoch 25 | train loss 1.2747
# epoch 26 | train loss 1.2723
# epoch 27 | train loss 1.2660
# epoch 28 | train loss 1.2617
# epoch 29 | train loss 1.2568
# epoch 30 | train loss 1.2555
# epoch 31 | train loss 1.2509
# epoch 32 | train loss 1.2434
# epoch 33 | train loss 1.2399
# epoch 34 | train loss 1.2335
# epoch 35 | train loss 1.2320
# epoch 36 | train loss 1.2297
# epoch 37 | train loss 1.2304
# epoch 38 | train loss 1.2227
# epoch 39 | train loss 1.2216
# epoch 40 | train loss 1.2184
# epoch 41 | train loss 1.2137
# epoch 42 | train loss 1.2156
# epoch 43 | train loss 1.2095
# epoch 44 | train loss 1.2100
# epoch 45 | train loss 1.2078
# epoch 46 | train loss 1.2035
# epoch 47 | train loss 1.1996
# epoch 48 | train loss 1.1994
# epoch 49 | train loss 1.1965
# epoch 50 | train loss 1.1962
# epoch 51 | train loss 1.1926
# epoch 52 | train loss 1.1917
# epoch 53 | train loss 1.1883
# epoch 54 | train loss 1.1887
# epoch 55 | train loss 1.1876
# epoch 56 | train loss 1.1826
# epoch 57 | train loss 1.1840
# epoch 58 | train loss 1.1792
# epoch 59 | train loss 1.1791
# epoch 60 | train loss 1.1792
# epoch 61 | train loss 1.1760
# epoch 62 | train loss 1.1775
# epoch 63 | train loss 1.1726
# epoch 64 | train loss 1.1714
# epoch 65 | train loss 1.1708
# epoch 66 | train loss 1.1655
# epoch 67 | train loss 1.1685
# epoch 68 | train loss 1.1664
# epoch 69 | train loss 1.1693
# epoch 70 | train loss 1.1656
# epoch 71 | train loss 1.1629
# epoch 72 | train loss 1.1605
# epoch 73 | train loss 1.1587
# epoch 74 | train loss 1.1558
# epoch 75 | train loss 1.1572
# epoch 76 | train loss 1.1574
# epoch 77 | train loss 1.1536
# epoch 78 | train loss 1.1549
# epoch 79 | train loss 1.1545
# epoch 80 | train loss 1.1527
# epoch 81 | train loss 1.1502
# epoch 82 | train loss 1.1495
# epoch 83 | train loss 1.1484
# epoch 84 | train loss 1.1460
# epoch 85 | train loss 1.1458
# epoch 86 | train loss 1.1484
# epoch 87 | train loss 1.1459
# epoch 88 | train loss 1.1433
# epoch 89 | train loss 1.1472
# epoch 90 | train loss 1.1410
# epoch 91 | train loss 1.1411
# epoch 92 | train loss 1.1426
# epoch 93 | train loss 1.1398
# epoch 94 | train loss 1.1375
# epoch 95 | train loss 1.1418
# epoch 96 | train loss 1.1378
# epoch 97 | train loss 1.1359
# epoch 98 | train loss 1.1390
# epoch 99 | train loss 1.1355

# %% [markdown]
# ## 5. Sampling

# %%
@torch.no_grad()
def sample_gpt(model, block_size, stoi, itos, device, start_text="ROMEO:", max_new_tokens=400):
    model.eval()
    context = torch.zeros((1, block_size), dtype=torch.long, device=device)
    for ch in start_text:
        if ch in stoi:
            ix = torch.tensor([[stoi[ch]]], device=device)
            context = torch.cat([context[:, 1:], ix], dim=1)
    out = list(start_text)
    for _ in range(max_new_tokens):
        logits = model(context)
        logits = logits[:, -1, :]
        probs = F.softmax(logits, dim=-1)
        ix = torch.multinomial(probs, num_samples=1)
        out.append(itos[ix.item()])
        context = torch.cat([context[:, 1:], ix], dim=1)
    return "".join(out)

print(sample_gpt(model, block_size, stoi, itos, device, start_text="ROMEO:", max_new_tokens=500))
# Out:
# ROMEO: Shall slew us ye thereof no God that thou shalt remair folly upon their fathers.
#
# 13:17 And the disciples spake in unto the river he son of
# Hebedma
# and Jacob, who found his commute hand on the trespass of Ammilial, came to utterly
# clean.
#
# 42:11 For Salun, which was they were numbered of the four flesh, because
# himself with him.
#
# 18:4 Free not every one what ye spake unto him out of Egypt, I have
# made you, but to bless them that gotteth into my house, and that
# hath spoken unto the Tumbasites: th

# %% [markdown]
# ## 6. 정리
#
# 이제 아주 작은 GPT 구조가 완성되었습니다.
#
# 전체 흐름은 다음과 같습니다.
#
# 1. bigram
# 2. MLP on names
# 3. MLP on Shakespeare
# 4. GPT-style dataset + minimal sequence model
# 5. single-head masked self-attention
# 6. tiny GPT
